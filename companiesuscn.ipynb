# %%
from pyalex import (
    Works, Authors, Sources,
    Institutions, Concepts, Publishers, Funders
)
import pyalex
import pandas as pd
import numpy as np
pyalex.config.email = "david@rs21.io"

### ssl problems
# https://support.chainstack.com/hc/en-us/articles/9117198436249-Common-SSL-Issues-on-Python-and-How-to-Fix-it

from flair.embeddings import DocumentPoolEmbeddings
from flair.data import Sentence
from flair.embeddings import SentenceTransformerDocumentEmbeddings

EMBEDDING_MODEL_1 = "all-mpnet-base-v2" 

# this one is also good: all-MiniLM-L6-v2
EMBEDDING_MODEL_2 = "all-MiniLM-L6-v2"
SENT_EMBEDDINGS_1 = SentenceTransformerDocumentEmbeddings(EMBEDDING_MODEL_1)
SENT_EMBEDDINGS_2 = SentenceTransformerDocumentEmbeddings(EMBEDDING_MODEL_2)
DOC_EMBEDDINGS= DocumentPoolEmbeddings([SENT_EMBEDDINGS_2])

import torch
from tqdm import tqdm
import yake
import umap.umap_ as umap
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.mixture import GaussianMixture as GMM
import altair as alt
import math
import plotly.express as px
import textwrap

# %%
def process_works_list(worklist:list):
    """
    transforms the 
    works list into a dataframe.
    """
    abstracts_dict = {h["id"]:h["abstract"] for h in worklist}
    df = pd.DataFrame.from_records(worklist)
    try: 
        del df['abstract_inverted_index'] # though don't all have abstracts is the problem
        df['abstract'] = df['id'].map(abstracts_dict)
    except:
        pass
   # df['author_affils'] = df['authorships'].apply(get_authors_and_affils)
    return df

# %%
from pyalex import config

config.max_retries = 0
config.retry_backoff_factor = 0.1
config.retry_http_codes = [429, 500, 503]

# %%
Works().filter(publication_year = '>2021',
        authorships={"institutions": {"country_code": "US",
                        "type": "company"}}).count()
# Out:
# 248000

# %% [markdown]
# https://github.com/J535D165/pyalex

# %%
Works().filter(publication_year = '>2021',
        authorships={"institutions": {"country_code": "US|CN",
                        "type": "company"}}).count()
# Out:
# 361080

# %%
Works().filter(publication_year = '>2019',
        authorships={"institutions": {"country_code": ["US","CN"]}}).filter(
        authorships={"institutions": {"country_code": "US",
                     "type": "company"}}).count()
# Out:
# 37879

# %%
Works().filter(publication_year = '>2020',
        authorships={"institutions": {"country_code":"CN|IR|RU"}}).filter(
        authorships={"institutions": {"country_code": "US",
                     "type": "company"}}).count()
# Out:
# 33890

# %%
def get_us_cn_frame():
    """
    takes a country_code and affil_type
    and forms the pagination object to retrive the 
    records
    """
    pager = Works().filter(publication_year = '>2020',
        authorships={"institutions": {"country_code":"CN|IR|RU"}}).filter(
        authorships={"institutions": {"country_code": "US",
                     "type": "company"}}).paginate(
        per_page = 200, n_max=None
                     )
    df = pd.DataFrame()
    for page in tqdm(pager):
        dfpage = process_works_list(page)
        df = pd.concat([df, dfpage], ignore_index=True)
        df.drop_duplicates(subset='id', keep='first',inplace=True)
    return df

# %%
df = get_us_cn_frame()
# Out:
# 171it [07:03,  2.48s/it]

# %%
#dftop = pd.concat(df,
#                  ignore_index=True)
dftop = df
dftop.drop_duplicates(subset='id', keep='first', 
                      inplace=True)

dftop.set_index('id', inplace=True, drop=False)

dfall = dftop
print(dfall.shape)

dfall['content'] = dfall['title'] + ". " + dfall['abstract']

dfrecords = dfall[~dfall['content'].isna()].copy()
# Out:
# (33890, 49)

# %%
def get_keywords(text:str, top:int=7, stopwords=None):
    """
    takes a blob of text and 
    returns the top **top** 
    keywords as a list
    """
    kw_extractor = yake.KeywordExtractor(top=top, stopwords=stopwords)
    keywords = kw_extractor.extract_keywords(text)
    return [p[0] for p in keywords]

# %%
def get_top_concepts(concept_list:list,score:float=.6):
    """
    takes a list of concept dictionaries 
    returns the top **top** display_names;
    concepts whose score is >= score
    """
    return [c['display_name'] for c in concept_list if c['score'] >= score]

# %%
dfrecords['keywords'] = dfrecords['content'].apply(get_keywords)
dfrecords['top_concepts'] = dfrecords['concepts'].apply(get_top_concepts)

# %%
texts = dfrecords['content'].str.lower().values.tolist()

# %%
def get_content_embeddings(dfrecords:pd.DataFrame) -> pd.DataFrame:
    """
    passes the preprocessed mitigation strings
    data through the embedding model to produce the vector
    space representation of each pet mitigation.
    """
    sent = Sentence("The grass is green.")
    DOC_EMBEDDINGS.embed(sent)
    texts = dfrecords["content"].str.lower().values.tolist()
    all_descriptions = np.empty((len(texts), len(sent.embedding)))
    for i in tqdm(range(len(texts))):
        sent = Sentence(texts[i])
        DOC_EMBEDDINGS.embed(sent)
        all_descriptions[i, :] = sent.embedding.cpu().numpy()
        # gc.collect()
        torch.cuda.empty_cache()
    dfcontentvectors = pd.DataFrame.from_records(all_descriptions, index=dfrecords.index)
    return dfcontentvectors

# %%
dfcontentvectors = get_content_embeddings(dfrecords)
# Out:
# 100%|███████████████████████████████████████████████████████████████████| 31109/31109 [14:57<00:00, 34.65it/s]

# %%
#umap.UMAP?
N_COMPONENTS = 2 # can visualize this way
umap_reducer = umap.UMAP(n_components=N_COMPONENTS,
                       #  metric='euclidean')
                         random_state=1234,
                         metric='cosine')  # can experiment with this metric as well as the other 
# parameters
# to see what other literature is in the same information space, we need to keep this umap_reducer 
# object as well as the gmm model below.

# Apply UMAP to the vectorized strings
reduced_vectors = umap_reducer.fit_transform(dfcontentvectors.to_numpy())
dfreduced = pd.DataFrame.from_records(reduced_vectors, 
                index=dfcontentvectors.index)
dfreduced.columns = ['x','y']
# Out:
# /home/davidd/.local/lib/python3.10/site-packages/umap/umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %% [markdown]
# # use hdbscan to cluster

# %%
import hdbscan

hdbscan_args = {'min_cluster_size': 15,
                            'metric': 'euclidean',
                            'cluster_selection_method': 'eom',
                            'cluster_selection_epsilon': 0.1
               }

cluster = hdbscan.HDBSCAN(**hdbscan_args).fit(dfreduced[['x','y']].to_numpy())

dfreduced['cluster'] = cluster.labels_
dfreduced['probability'] = cluster.probabilities_

dfpapers = dfrecords.merge(dfreduced, left_index=True,
                           right_index=True)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
#help(dfpapers.explode)
del dfpapers['id']
dfstart = dfpapers.reset_index()
dfstart.head()
# Out:
#                                  id  \
# 0  https://openalex.org/W3041133507
# 1  https://openalex.org/W4225854071
# 2  https://openalex.org/W4283271244
# 3  https://openalex.org/W3171517418
# 4  https://openalex.org/W4220999759
#
#                                              doi  \
# 0     https://doi.org/10.1109/jproc.2020.3004555
# 1          https://doi.org/10.1056/nejmoa2114583
# 2     https://doi.org/10.1038/s41375-022-01613-1
# 3  https://doi.org/10.1016/s0140-6736(21)00797-2
# 4        https://doi.org/10.1126/science.abj6987
#
#                                                title  \
# 0        A Comprehensive Survey on Transfer Learning
# 1  Waning Immune Humoral Response to BNT162b2 Cov...
# 2  The 5th edition of the World Health Organizati...
# 3  First-line nivolumab plus chemotherapy versus ...
# 4            The complete sequence of a human genome
#
#                                         display_name  publication_year  \
# 0        A Comprehensive Survey on Transfer Learning              2021
# 1  Waning Immune Humoral Response to BNT162b2 Cov...              2021
# 2  The 5th edition of the World Health Organizati...              2022
# 3  First-line nivolumab plus chemotherapy versus ...              2021
# 4            The complete sequence of a human genome              2022
#
#   publication_date                                                ids  \
# 0       2021-01-01  {'openalex': 'https://openalex.org/W3041133507...
# 1       2021-12-09  {'openalex': 'https://openalex.org/W4225854071...
# 2       2022-06-22  {'openalex': 'https://openalex.org/W4283271244...
# 3       2021-07-01  {'openalex': 'https://openalex.org/W3171517418...
# 4       2022-04-01  {'openalex': 'https://openalex.org/W4220999759...
#
#   language                                   primary_location     type  ...  \
# 0       en  {'is_oa': False, 'landing_page_url': 'https://...  article  ...
# 1       en  {'is_oa': True, 'landing_page_url': 'https://d...  article  ...
# 2       en  {'is_oa': True, 'landing_page_url': 'https://d...  article  ...
# 3       en  {'is_oa': False, 'landing_page_url': 'https://...  article  ...
# 4       en  {'is_oa': False, 'landing_page_url': 'https://...  article  ...
#
#   created_date fulltext_origin is_authors_truncated  \
# 0   2020-07-16             NaN                  NaN
# 1   2022-05-05             pdf                  NaN
# 2   2022-06-23             pdf                  NaN
# 3   2021-06-22             NaN                  NaN
# 4   2022-04-03             pdf                  NaN
#
#                                             abstract  \
# 0  Transfer learning aims at improving the perfor...
# 1  Despite high vaccine coverage and effectivenes...
# 2  The upcoming 5th edition of the World Health O...
# 3  First-line chemotherapy for advanced or metast...
# 4  Since its initial release in 2000, the human r...
#
#                                              content  \
# 0  A Comprehensive Survey on Transfer Learning. T...
# 1  Waning Immune Humoral Response to BNT162b2 Cov...
# 2  The 5th edition of the World Health Organizati...
# 3  First-line nivolumab plus chemotherapy versus ...
# 4  The complete sequence of a human genome. Since...
#
#                                         top_concepts         x         y  \
# 0           [Transfer of learning, Computer science]  5.702897  4.143548
# 1  [Medicine, Neutralizing antibody, Incidence (g... -0.253714  5.305731
# 2                              [Histiocyte, Myeloid] -5.298151  3.350824
# 3  [Medicine, Oxaliplatin, Nivolumab, Internal me... -6.409124  1.994749
# 4  [Euchromatin, Genome, Human genome, Telomere, ... -1.735086  7.104193
#
#   cluster probability
# 0     183         1.0
# 1      77         1.0
# 2      -1         0.0
# 3     188         1.0
# 4     110         1.0
#
# [5 rows x 55 columns]

# %%
dfstart['publication_year'].value_counts(dropna=False)
# Out:
# 2021    9732
# 2022    9514
# 2023    8854
# 2024    3007
# 2025       2
# Name: publication_year, dtype: int64

# %%
dfstart.shape
# Out:
# (31109, 55)

# %%
dfbig = dfstart.explode(column='authorships')
dfbig.shape, dfstart.shape
# Out:
# ((394355, 55), (31109, 55))

# %%
def add_extra_to_authorships(row: pd.DataFrame):
    """
    row[authorships] is a dictionary;
    add in the id key to that dictionary
    whose value is row[id]
    """
    complete_dict = row["authorships"]
   # assert type(complete_dict) == dict
    #print(type(complete_dict))
    if type(complete_dict) == dict:
        complete_dict["id"] = row["id"]
        complete_dict["x"] = row["x"]
        complete_dict["y"] = row["y"]
        complete_dict["cluster"] = row["cluster"]
        complete_dict["cluster_score"] = row["probability"]
        complete_dict["title"] = row["title"]
        complete_dict["abstract"] = row["abstract"]
        complete_dict["doi"] = row["doi"]
        complete_dict["publication_date"] = row["publication_date"]
        complete_dict["publication_year"] = row["publication_year"]
        complete_dict["grants"] = row["grants"]
        complete_dict["locations"] = row["locations"]
        return complete_dict
    else:
        return row["authorships"]

# %%
dfbig['big_authorships'] = dfbig.apply(add_extra_to_authorships, axis=1)

# %%
#dfbig['authorships'].tolist()
bigvals = dfbig['authorships'].tolist()

# %%
dictvals = [c for c in bigvals if type(c) != float]

# %%
dictvals[0]['author'].keys()
# Out:
# dict_keys(['id', 'display_name', 'orcid'])

# %%
dftriple = pd.json_normalize(dictvals,
                  record_path=['institutions'],
                  meta=['id','raw_affiliation_strings','author_position', 'doi',
                        'title','abstract','publication_date', 'publication_year',
                        'grants','locations',
                        'is_corrresponding','x','y','cluster','cluster_score',
                       ['author','id'], ['author', 'display_name'],
                       ['author','orcid']],
                  errors='ignore',
                  sep='_',
                  meta_prefix='paper_',
                #  record_prefix='author_'
                 )

# %%
dftopics = dfcontentvectors.copy()
dftopics['cluster'] = dfpapers['cluster']
dfmeantopics = dftopics.groupby('cluster').mean().copy()
reduced_topics = umap_reducer.transform(dfmeantopics.to_numpy())
df_reduced_topics = pd.DataFrame.from_records(reduced_topics, 
                index=dfmeantopics.index)
df_reduced_topics.columns = ['x','y']
df_reduced_topics['topic'] = df_reduced_topics.index
df_reduced_topics.head()

def get_cluster_concepts(topic_num:int, n:int=20):
    """
    takes an integer topic_num corresponding to a 
    given topic number and
    returns the list of top n occuring concepts
    from the top_concept field
    """
    top_concepts = dfpapers[dfpapers['cluster'] == topic_num]['top_concepts'].tolist()
    flat_concepts = [item for sublist in top_concepts for item in sublist]
    concepts_dict = {c:flat_concepts.count(c) for c in flat_concepts}
    sorted_concepts = sorted(concepts_dict.items(), key=lambda x:x[1], reverse=True)
    return [c[0] for c in sorted_concepts][:n]

def get_yake_cluster_phrases(topic_num:int, n:int=20):
    """
    takes in an integer n corresponding
    to a given topic number and
    returns the list of keyphrases (TopicRank method)
    """
    documents = dfpapers[dfpapers['cluster'] == topic_num]['content'].tolist()
    topic_input = ". ".join(documents)
    #extractor = pke.unsupervised.TextRank()
    kw_extractor = yake.KeywordExtractor(top=n, stopwords=None)
    keywords = kw_extractor.extract_keywords(topic_input)
    #extractor.load_document(input=topic_input,
    #                    language='en',
    #                    normalization=None)

    #extractor.candidate_selection()

    #window = 2
    #use_stems = False
    #extractor.candidate_weighting(window=window,
    #                          use_stems=use_stems)
    #extractor.candidate_weighting()
    #threshold = 0.8
   # keyphrases = extractor.get_n_best(n=20, threshold=threshold)
    #keyphrases = extractor.get_n_best(n=n)
    return [p[0] for p in keywords]

wikiconcepts = df_reduced_topics['topic'].apply(get_cluster_concepts)

wikikeywords = df_reduced_topics['topic'].apply(get_yake_cluster_phrases)

dfpapers['id'] = dfpapers.index
dfinfo = dfpapers[['x','y','id','title','doi','cluster','grants',
                   'locations',
                 'publication_date','keywords','top_concepts']].copy()

centroids = dfinfo.groupby('cluster')[['x','y']].mean().copy()
centroids['concepts'] = wikiconcepts
centroids['cluster'] = centroids.index
centroids['keywords'] = wikikeywords

# %%
def wrap_it(x):
    return "<br>".join(textwrap.wrap(x, width=40))
   # return "<br>".join(textwrap.wrap(x.replace(r'\s+', ' '), width=40))

# %%
centroids['wrapped_keywords'] = centroids['keywords'].apply(str).apply(wrap_it)
centroids['wrapped_concepts'] = centroids['concepts'].apply(str).apply(wrap_it)

# %%
centroids.to_pickle('updatejammingcentroids2d.pkl')

# %%
dftriple.to_pickle('updatejammingdftriple2d.pkl')

# %%
def get_affils_cluster_sort(dc:pd.DataFrame, cl:int):
    """
    restricts the dataframe dc to cluster value cl
    and returns the results grouped by id, ror sorted
    by the some of probablity descending
    """
    dg = dc[dc['paper_cluster'] == cl].copy()
    print(cl)
    dv = dg.groupby(['id','display_name','country_code',
                     'type'])['paper_cluster_score'].sum().to_frame()
    dv.sort_values('paper_cluster_score', ascending=False, inplace=True)
    kw = centroids[centroids.cluster == cl]['keywords'].iloc[0]
    return dv, kw

# %%
dv84, kw84 = get_affils_cluster_sort(dftriple, 1)
print(kw84)
dv84.head(10)
# Out:
# 1
# ['Continuing Medical Education', 'Medical Education Institute', 'Lippincott Continuing Medical', 'CME Accreditation Lippincott', 'Lippincott Professional Development', 'NCPD Accreditation Lippincott', 'Accreditation Lippincott Continuing', 'continuing professional development', 'Accreditation Lippincott Professional', 'Continuing Medical', 'Medical Education', 'nursing continuing professional', 'continuing nursing education', 'Professional Development', 'provide continuing medical', 'AMA PRA Category', 'Education Institute', 'Accreditation Lippincott', 'CME Accreditation', 'Lippincott Continuing']
#                                                                                                            paper_cluster_score
# id                               display_name                                       country_code type
# https://openalex.org/I4210162565 Chongqing Electromechanical Holdings (China)       CN           company             138.74078
# https://openalex.org/I4210143747 Medical Education Institute                        US           nonprofit           138.74078
# https://openalex.org/I865767359  Accreditation Council for Graduate Medical Educ... US           nonprofit          137.169771
# https://openalex.org/I2800773984 American Nurses Credentialing Center               US           other              127.233348
# https://openalex.org/I200777214  National and Kapodistrian University of Athens     GR           education           37.936086
# https://openalex.org/I40347166   University of Chicago                              US           education           37.936086
# https://openalex.org/I1337397194 Emerald Group Publishing (United Kingdom)          GB           company             37.936086
# https://openalex.org/I39422238   University of Illinois at Chicago                  US           education           37.936086
# https://openalex.org/I4210097017 Universitatea Danubius Galati                      RO           education           37.936086
# https://openalex.org/I4210098396 Indo-American Center                               US           nonprofit           37.936086

# %%
dv84, kw84 = get_affils_cluster_sort(dftriple, 0)
print(kw84)
dv84.head(10)
# Out:
# 0
# ['MACIE', 'evolutionarily conserved', 'regulatory functional', 'functional', 'MACIE score', 'conserved', 'Class Integrative Estimation', 'Annotation Class Integrative', 'estimated posterior probability', 'Multi-dimensional Annotation Class', 'evolutionarily', 'regulatory', 'estimated posterior', 'posterior', 'posterior probability', 'MACIE integrates', 'estimated', 'Integrative Estimation', 'Roadmap Epigenomics', 'Class Integrative']
#                                                                                                             paper_cluster_score
# id                               display_name                                       country_code type
# https://openalex.org/I2801228662 Peking Union Medical College Hospital              CN           healthcare                72.0
# https://openalex.org/I200296433  Chinese Academy of Medical Sciences & Peking Un... CN           education                 72.0
# https://openalex.org/I136199984  Harvard University                                 US           education                 48.0
# https://openalex.org/I157773358  Sun Yat-sen University                             CN           education                 32.0
# https://openalex.org/I4210128615 Chinese Academy of Forestry                        CN           government                16.0
# https://openalex.org/I204823248  Huazhong Agricultural University                   CN           education                 16.0
# https://openalex.org/I4210093460 Sixth Affiliated Hospital of Sun Yat-sen Univer... CN           healthcare                16.0
# https://openalex.org/I4210098034 Key Laboratory of Guangdong Province               CN           facility                  16.0
# https://openalex.org/I197869895  Anhui Medical University                           CN           education                 16.0
# https://openalex.org/I78577930   Columbia University                                US           education                 16.0

# %%
dv84, kw84 = get_affils_cluster_sort(dftriple, 51)
print(kw84)
dv84.head(20)
# Out:
# 51
# ['Lithium-ion batteries', 'Battery', 'model', 'lithium-ion batteries based', 'batteries', 'battery SOH estimation', 'estimation', 'SOC estimation method', 'method', 'SOC', 'lithium-ion battery', 'SOC estimation', 'based', 'lithium-ion', 'batteries based', 'fault diagnosis methods', 'electrochemical model', 'models', 'estimation method based', 'lithium-ion battery models']
#                                                                                                            paper_cluster_score
# id                               display_name                                       country_code type
# https://openalex.org/I204983213  Harbin Institute of Technology                     CN           education           27.843065
# https://openalex.org/I4210156703 The Faraday Institution                            GB           nonprofit           12.047498
# https://openalex.org/I4210156197 Life Cycle Engineering (United States)             US           company             10.796044
# https://openalex.org/I66946132   University of Maryland, College Park               US           education           10.269602
# https://openalex.org/I99065089   Tsinghua University                                CN           education            8.053132
# https://openalex.org/I4210157719 Yancheng Institute of Technology                   CN           education            7.044918
# https://openalex.org/I158842170  Chongqing University                               CN           education                 7.0
# https://openalex.org/I116953780  Tongji University                                  CN           education              6.9569
# https://openalex.org/I74872605   China Southern Power Grid (China)                  CN           company              6.287389
# https://openalex.org/I153473198  North China Electric Power University              CN           education                 6.0
# https://openalex.org/I47508984   Imperial College London                            GB           education            5.575172
# https://openalex.org/I63966007   Massachusetts Institute of Technology              US           education                 5.0
# https://openalex.org/I4210148646 Clean Energy (United States)                       US           company               4.71591
# https://openalex.org/I16365422   Hefei University of Technology                     CN           education            4.601513
# https://openalex.org/I4210130704 University of Michigan–Dearborn                    US           education            4.109156
# https://openalex.org/I150229711  University of Electronic Science and Technology... CN           education            4.085345
# https://openalex.org/I4210153393 Geely (China)                                      CN           company                   4.0
# https://openalex.org/I204250578  University of California, Irvine                   US           education            3.996216
# https://openalex.org/I4210089887 Dyson (United Kingdom)                             GB           company              3.165672
# https://openalex.org/I4210115951 Medical Components (United States)                 US           company                   3.0

# %%
dfinfo = dfpapers[['x','y','id','title','doi','cluster','probability',
                 'publication_date','grants','locations',
                   'keywords','top_concepts']].copy()

# %%
# Group by 'paper_id' and concatenate 'paper_raw_affiliation_strings'
grouped = dftriple.groupby('paper_id')['paper_raw_affiliation_strings'].apply(lambda x: list(set([item for sublist in x for item in sublist]))).reset_index()

# Convert the series back to a dictionary
pap_affils_dict = grouped.set_index('paper_id')['paper_raw_affiliation_strings'].to_dict()

# %%
import itertools

# %%
pap_authors_dict = dftriple.groupby('paper_id')['paper_author_display_name'].apply(lambda x: x.values)

# %%
dfinfo['affil_list'] = dfinfo['id'].map(pap_affils_dict)

# %%
dfinfo['author_list'] = dfinfo['id'].map(pap_authors_dict)

# %%
dfinfo['wrapped_affil_list'] = dfinfo['affil_list'].apply(str).apply(wrap_it)
dfinfo['wrapped_author_list'] = dfinfo['author_list'].apply(str).apply(wrap_it)

# %%
dfinfo['wrapped_keywords'] = dfinfo['keywords'].apply(str).apply(wrap_it)

# %%
def get_source_name(loc_list):
    """
    grab the first item in the list;
    retturn the display name
    """
    try:
        primary = loc_list[0]
        return primary["source"]["display_name"]
    except:
        return None

def get_source_type(loc_list):
    """
    grab the first item in the list;
    return the source type
    """
    try:
        primary = loc_list[0]
        return primary["source"]["type"]
    except:
        return None

# %%
dfinfo["source"] = dfinfo["locations"].apply(get_source_name)
dfinfo["source_type"] = dfinfo["locations"].apply(get_source_type)

# %%
dfinfo.to_pickle('updatejammingdfinfo2d.pkl')

# %%
def get_funder_names(funder_list):
    """
    funder_list is a list of dictionaries
    with three keys; return the list of 
    unique **funder_display_name**
    values
    """
    try:
        funder_names = list(set([f['funder_display_name'] for f in funder_list]))
        return funder_names    
    except:
        return []

# %%
dftriple["source"] = dftriple["paper_locations"].apply(get_source_name)
dftriple["source_type"] = dftriple["paper_locations"].apply(get_source_type)
dftriple["funder_list"] = dftriple["paper_grants"].apply(get_funder_names)

# %%
dftriple.to_pickle('updatejammingdftriple2d.pkl')

# %%
def get_journals_cluster_sort(dc:pd.DataFrame, cl:int):
    """
    restricts the dataframe dc to cluster value cl
    and returns the results grouped by source (where
    source_type == 'journal') sorted
    by the some of probablity descending
    """
    dg = dc[dc['paper_cluster'] == cl].copy()
    print(cl)
    dv = dg[dg['source_type'] == 'journal'].groupby(['source'])['paper_cluster_score'].sum().to_frame()
    dv.sort_values('paper_cluster_score', ascending=False, inplace=True)
    kw = centroids[centroids.cluster == cl]['keywords'].iloc[0]
    return dv, kw

# %%
def get_conferences_cluster_sort(dc:pd.DataFrame, cl:int):
    """
    restricts the dataframe dc to cluster value cl
    and returns the results grouped by source (where
    source_type == 'journal') sorted
    by the some of probablity descending
    """
    dg = dc[dc['paper_cluster'] == cl].copy()
    print(cl)
    dv = dg[dg['source_type'] == 'conference'].groupby(['source'])['paper_cluster_score'].sum().to_frame()
    dv.sort_values('paper_cluster_score', ascending=False, inplace=True)
    kw = centroids[centroids.cluster == cl]['keywords'].iloc[0]
    return dv, kw

# %%
def get_country_collaborations_sort(dc:pd.DataFrame, cl:int):
    """
    resticts the dataframe dc to cluster value cl
    and returns the results of paper_id s where there is 
    more than one country_code
    """
    dg = dc[dc['paper_cluster'] == cl].copy()
    dv = dg.groupby('paper_id')['country_code'].apply(lambda x: len(set(x.values))).to_frame()
    dc = dg.groupby('paper_id')['country_code'].apply(lambda x: list(set(x.values))).to_frame()
    dc.columns = ['collab_countries']
    dv.columns = ['country_count']
    dv['collab_countries'] = dc['collab_countries']
    dv.sort_values('country_count',ascending=False, inplace=True)
    di = dfinfo.loc[dv.index].copy()
    di['country_count'] = dv['country_count']
    di['collab_countries'] = dv['collab_countries']
    return di[di['country_count'] > 1]

# %%
dv = get_country_collaborations_sort(dftriple, 0)
dv
# Out:
#                                           x          y  \
# paper_id
# https://openalex.org/W4393413673  12.451026   8.406316
# https://openalex.org/W4393529795  12.451130   8.406391
# https://openalex.org/W4393593906  12.451165   8.406417
# https://openalex.org/W4393617317  12.451202   8.406441
# https://openalex.org/W4393641940  12.451254   8.406468
# https://openalex.org/W4393736355  12.451313   8.406501
# https://openalex.org/W4393742852  12.451364   8.406528
# https://openalex.org/W4393819632  12.451362   8.406533
# https://openalex.org/W4394071783  11.703955  10.044555
# https://openalex.org/W4394150963  11.704035  10.044626
# https://openalex.org/W4394155442  11.704038  10.044646
# https://openalex.org/W4394363642  11.704076  10.044688
# https://openalex.org/W4394402060  11.704129  10.044719
# https://openalex.org/W4394415133  11.704163  10.044741
# https://openalex.org/W4394419950  11.704207  10.044804
# https://openalex.org/W4394503207  11.704228  10.044821
#
#                                                                 id  \
# paper_id
# https://openalex.org/W4393413673  https://openalex.org/W4393413673
# https://openalex.org/W4393529795  https://openalex.org/W4393529795
# https://openalex.org/W4393593906  https://openalex.org/W4393593906
# https://openalex.org/W4393617317  https://openalex.org/W4393617317
# https://openalex.org/W4393641940  https://openalex.org/W4393641940
# https://openalex.org/W4393736355  https://openalex.org/W4393736355
# https://openalex.org/W4393742852  https://openalex.org/W4393742852
# https://openalex.org/W4393819632  https://openalex.org/W4393819632
# https://openalex.org/W4394071783  https://openalex.org/W4394071783
# https://openalex.org/W4394150963  https://openalex.org/W4394150963
# https://openalex.org/W4394155442  https://openalex.org/W4394155442
# https://openalex.org/W4394363642  https://openalex.org/W4394363642
# https://openalex.org/W4394402060  https://openalex.org/W4394402060
# https://openalex.org/W4394415133  https://openalex.org/W4394415133
# https://openalex.org/W4394419950  https://openalex.org/W4394419950
# https://openalex.org/W4394503207  https://openalex.org/W4394503207
#
#                                                                               title  \
# paper_id
# https://openalex.org/W4393413673  MACIE scores for human genome assembly GRCh37 ...
# https://openalex.org/W4393529795  MACIE scores for human genome assembly GRCh37 ...
# https://openalex.org/W4393593906  MACIE scores for human genome assembly GRCh37 ...
# https://openalex.org/W4393617317  MACIE scores for human genome assembly GRCh37 ...
# https://openalex.org/W4393641940  MACIE scores for human genome assembly GRCh37 ...
# https://openalex.org/W4393736355  MACIE scores for human genome assembly GRCh37 ...
# https://openalex.org/W4393742852  MACIE scores for human genome assembly GRCh37 ...
# https://openalex.org/W4393819632  MACIE scores for human genome assembly GRCh37 ...
# https://openalex.org/W4394071783  Additional file 7 of The spatiotemporal regula...
# https://openalex.org/W4394150963  Additional file 3 of The spatiotemporal regula...
# https://openalex.org/W4394155442  Additional file 6 of The spatiotemporal regula...
# https://openalex.org/W4394363642  Additional file 9 of The spatiotemporal regula...
# https://openalex.org/W4394402060  Additional file 4 of The spatiotemporal regula...
# https://openalex.org/W4394415133  Additional file 2 of The spatiotemporal regula...
# https://openalex.org/W4394419950  Additional file 8 of The spatiotemporal regula...
# https://openalex.org/W4394503207  Additional file 5 of The spatiotemporal regula...
#
#                                                                            doi  \
# paper_id
# https://openalex.org/W4393413673        https://doi.org/10.5281/zenodo.5755656
# https://openalex.org/W4393529795        https://doi.org/10.5281/zenodo.5755655
# https://openalex.org/W4393593906        https://doi.org/10.5281/zenodo.5756449
# https://openalex.org/W4393617317        https://doi.org/10.5281/zenodo.5756448
# https://openalex.org/W4393641940        https://doi.org/10.5281/zenodo.5756478
# https://openalex.org/W4393736355        https://doi.org/10.5281/zenodo.5756562
# https://openalex.org/W4393742852        https://doi.org/10.5281/zenodo.5756563
# https://openalex.org/W4393819632        https://doi.org/10.5281/zenodo.5756479
# https://openalex.org/W4394071783  https://doi.org/10.6084/m9.figshare.20408323
# https://openalex.org/W4394150963  https://doi.org/10.6084/m9.figshare.20408311
# https://openalex.org/W4394155442  https://doi.org/10.6084/m9.figshare.20408320
# https://openalex.org/W4394363642  https://doi.org/10.6084/m9.figshare.20408329
# https://openalex.org/W4394402060  https://doi.org/10.6084/m9.figshare.20408314
# https://openalex.org/W4394415133  https://doi.org/10.6084/m9.figshare.20408308
# https://openalex.org/W4394419950  https://doi.org/10.6084/m9.figshare.20408326
# https://openalex.org/W4394503207  https://doi.org/10.6084/m9.figshare.20408317
#
#                                   cluster  probability publication_date  \
# paper_id
# https://openalex.org/W4393413673        0          1.0       2021-12-08
# https://openalex.org/W4393529795        0          1.0       2021-12-08
# https://openalex.org/W4393593906        0          1.0       2021-12-08
# https://openalex.org/W4393617317        0          1.0       2021-12-08
# https://openalex.org/W4393641940        0          1.0       2021-12-08
# https://openalex.org/W4393736355        0          1.0       2021-12-08
# https://openalex.org/W4393742852        0          1.0       2021-12-08
# https://openalex.org/W4393819632        0          1.0       2021-12-08
# https://openalex.org/W4394071783        0          1.0       2022-01-01
# https://openalex.org/W4394150963        0          1.0       2022-01-01
# https://openalex.org/W4394155442        0          1.0       2022-01-01
# https://openalex.org/W4394363642        0          1.0       2022-01-01
# https://openalex.org/W4394402060        0          1.0       2022-01-01
# https://openalex.org/W4394415133        0          1.0       2022-01-01
# https://openalex.org/W4394419950        0          1.0       2022-01-01
# https://openalex.org/W4394503207        0          1.0       2022-01-01
#
#                                  grants  \
# paper_id
# https://openalex.org/W4393413673     []
# https://openalex.org/W4393529795     []
# https://openalex.org/W4393593906     []
# https://openalex.org/W4393617317     []
# https://openalex.org/W4393641940     []
# https://openalex.org/W4393736355     []
# https://openalex.org/W4393742852     []
# https://openalex.org/W4393819632     []
# https://openalex.org/W4394071783     []
# https://openalex.org/W4394150963     []
# https://openalex.org/W4394155442     []
# https://openalex.org/W4394363642     []
# https://openalex.org/W4394402060     []
# https://openalex.org/W4394415133     []
# https://openalex.org/W4394419950     []
# https://openalex.org/W4394503207     []
#
#                                                                           locations  \
# paper_id
# https://openalex.org/W4393413673  [{'is_oa': True, 'landing_page_url': 'https://...
# https://openalex.org/W4393529795  [{'is_oa': True, 'landing_page_url': 'https://...
# https://openalex.org/W4393593906  [{'is_oa': True, 'landing_page_url': 'https://...
# https://openalex.org/W4393617317  [{'is_oa': True, 'landing_page_url': 'https://...
# https://openalex.org/W4393641940  [{'is_oa': True, 'landing_page_url': 'https://...
# https://openalex.org/W4393736355  [{'is_oa': True, 'landing_page_url': 'https://...
# https://openalex.org/W4393742852  [{'is_oa': True, 'landing_page_url': 'https://...
# https://openalex.org/W4393819632  [{'is_oa': True, 'landing_page_url': 'https://...
# https://openalex.org/W4394071783  [{'is_oa': True, 'landing_page_url': 'https://...
# https://openalex.org/W4394150963  [{'is_oa': True, 'landing_page_url': 'https://...
# https://openalex.org/W4394155442  [{'is_oa': True, 'landing_page_url': 'https://...
# https://openalex.org/W4394363642  [{'is_oa': True, 'landing_page_url': 'https://...
# https://openalex.org/W4394402060  [{'is_oa': True, 'landing_page_url': 'https://...
# https://openalex.org/W4394415133  [{'is_oa': True, 'landing_page_url': 'https://...
# https://openalex.org/W4394419950  [{'is_oa': True, 'landing_page_url': 'https://...
# https://openalex.org/W4394503207  [{'is_oa': True, 'landing_page_url': 'https://...
#
#                                   ...                top_concepts  \
# paper_id                          ...
# https://openalex.org/W4393413673  ...                          []
# https://openalex.org/W4393529795  ...                          []
# https://openalex.org/W4393593906  ...                          []
# https://openalex.org/W4393617317  ...                          []
# https://openalex.org/W4393641940  ...                          []
# https://openalex.org/W4393736355  ...                          []
# https://openalex.org/W4393742852  ...                          []
# https://openalex.org/W4393819632  ...                          []
# https://openalex.org/W4394071783  ...  [Inflorescence, Fagopyrum]
# https://openalex.org/W4394150963  ...  [Inflorescence, Fagopyrum]
# https://openalex.org/W4394155442  ...  [Inflorescence, Fagopyrum]
# https://openalex.org/W4394363642  ...  [Inflorescence, Fagopyrum]
# https://openalex.org/W4394402060  ...  [Inflorescence, Fagopyrum]
# https://openalex.org/W4394415133  ...  [Inflorescence, Fagopyrum]
# https://openalex.org/W4394419950  ...  [Inflorescence, Fagopyrum]
# https://openalex.org/W4394503207  ...  [Inflorescence, Fagopyrum]
#
#                                                                          affil_list  \
# paper_id
# https://openalex.org/W4393413673  [Department of Pathology and Laboratory Medici...
# https://openalex.org/W4393529795  [Department of Pathology and Laboratory Medici...
# https://openalex.org/W4393593906  [Department of Pathology and Laboratory Medici...
# https://openalex.org/W4393617317  [Department of Pathology and Laboratory Medici...
# https://openalex.org/W4393641940  [Genentech/Roche, School of Statistics, Southw...
# https://openalex.org/W4393736355  [Department of Pathology and Laboratory Medici...
# https://openalex.org/W4393742852  [Department of Pathology and Laboratory Medici...
# https://openalex.org/W4393819632  [Genentech/Roche, School of Statistics, Southw...
# https://openalex.org/W4394071783  [Anhui Medical University, Shanghai Tenth Peop...
# https://openalex.org/W4394150963  [Anhui Medical University, Shanghai Tenth Peop...
# https://openalex.org/W4394155442  [Anhui Medical University, Shanghai Tenth Peop...
# https://openalex.org/W4394363642  [Anhui Medical University, Shanghai Tenth Peop...
# https://openalex.org/W4394402060  [Anhui Medical University, Shanghai Tenth Peop...
# https://openalex.org/W4394415133  [Anhui Medical University, Shanghai Tenth Peop...
# https://openalex.org/W4394419950  [Anhui Medical University, Shanghai Tenth Peop...
# https://openalex.org/W4394503207  [Anhui Medical University, Shanghai Tenth Peop...
#
#                                                                         author_list  \
# paper_id
# https://openalex.org/W4393413673  [Xihao Li, Godwin Yung, Hufeng Zhou, Ryan Sun,...
# https://openalex.org/W4393529795  [Xihao Li, Godwin Yung, Hufeng Zhou, Ryan Sun,...
# https://openalex.org/W4393593906  [Xihao Li, Godwin Yung, Hufeng Zhou, Ryan Sun,...
# https://openalex.org/W4393617317  [Xihao Li, Godwin Yung, Hufeng Zhou, Ryan Sun,...
# https://openalex.org/W4393641940  [Xihao Li, Godwin Yung, Hufeng Zhou, Ryan Sun,...
# https://openalex.org/W4393736355  [Xihao Li, Godwin Yung, Hufeng Zhou, Ryan Sun,...
# https://openalex.org/W4393742852  [Xihao Li, Godwin Yung, Hufeng Zhou, Ryan Sun,...
# https://openalex.org/W4393819632  [Xihao Li, Godwin Yung, Hufeng Zhou, Ryan Sun,...
# https://openalex.org/W4394071783  [Xinwei Guo, Xinwei Guo, Xinwei Guo, Zuliang L...
# https://openalex.org/W4394150963  [Xinwei Guo, Xinwei Guo, Xinwei Guo, Xinwei Gu...
# https://openalex.org/W4394155442  [Xinwei Guo, Xinwei Guo, Xinwei Guo, Zuliang L...
# https://openalex.org/W4394363642  [Xinwei Guo, Xinwei Guo, Xinwei Guo, Xinwei Gu...
# https://openalex.org/W4394402060  [Xinwei Guo, Xinwei Guo, Xinwei Guo, Zuliang L...
# https://openalex.org/W4394415133  [Xinwei Guo, Xinwei Guo, Xinwei Guo, Zuliang L...
# https://openalex.org/W4394419950  [Xinwei Guo, Xinwei Guo, Xinwei Guo, Xinwei Gu...
# https://openalex.org/W4394503207  [Xinwei Guo, Xinwei Guo, Xinwei Guo, Zuliang L...
#
#                                                                  wrapped_affil_list  \
# paper_id
# https://openalex.org/W4393413673  ['Department of Pathology and Laboratory<br>Me...
# https://openalex.org/W4393529795  ['Department of Pathology and Laboratory<br>Me...
# https://openalex.org/W4393593906  ['Department of Pathology and Laboratory<br>Me...
# https://openalex.org/W4393617317  ['Department of Pathology and Laboratory<br>Me...
# https://openalex.org/W4393641940  ['Genentech/Roche', 'School of<br>Statistics, ...
# https://openalex.org/W4393736355  ['Department of Pathology and Laboratory<br>Me...
# https://openalex.org/W4393742852  ['Department of Pathology and Laboratory<br>Me...
# https://openalex.org/W4393819632  ['Genentech/Roche', 'School of<br>Statistics, ...
# https://openalex.org/W4394071783  ['Anhui Medical University', "Shanghai<br>Tent...
# https://openalex.org/W4394150963  ['Anhui Medical University', "Shanghai<br>Tent...
# https://openalex.org/W4394155442  ['Anhui Medical University', "Shanghai<br>Tent...
# https://openalex.org/W4394363642  ['Anhui Medical University', "Shanghai<br>Tent...
# https://openalex.org/W4394402060  ['Anhui Medical University', "Shanghai<br>Tent...
# https://openalex.org/W4394415133  ['Anhui Medical University', "Shanghai<br>Tent...
# https://openalex.org/W4394419950  ['Anhui Medical University', "Shanghai<br>Tent...
# https://openalex.org/W4394503207  ['Anhui Medical University', "Shanghai<br>Tent...
#
#                                                                 wrapped_author_list  \
# paper_id
# https://openalex.org/W4393413673  ['Xihao Li' 'Godwin Yung' 'Hufeng Zhou'<br>'Ry...
# https://openalex.org/W4393529795  ['Xihao Li' 'Godwin Yung' 'Hufeng Zhou'<br>'Ry...
# https://openalex.org/W4393593906  ['Xihao Li' 'Godwin Yung' 'Hufeng Zhou'<br>'Ry...
# https://openalex.org/W4393617317  ['Xihao Li' 'Godwin Yung' 'Hufeng Zhou'<br>'Ry...
# https://openalex.org/W4393641940  ['Xihao Li' 'Godwin Yung' 'Hufeng Zhou'<br>'Ry...
# https://openalex.org/W4393736355  ['Xihao Li' 'Godwin Yung' 'Hufeng Zhou'<br>'Ry...
# https://openalex.org/W4393742852  ['Xihao Li' 'Godwin Yung' 'Hufeng Zhou'<br>'Ry...
# https://openalex.org/W4393819632  ['Xihao Li' 'Godwin Yung' 'Hufeng Zhou'<br>'Ry...
# https://openalex.org/W4394071783  ['Xinwei Guo' 'Xinwei Guo' 'Xinwei Guo'<br>'Zu...
# https://openalex.org/W4394150963  ['Xinwei Guo' 'Xinwei Guo' 'Xinwei Guo'<br>'Xi...
# https://openalex.org/W4394155442  ['Xinwei Guo' 'Xinwei Guo' 'Xinwei Guo'<br>'Zu...
# https://openalex.org/W4394363642  ['Xinwei Guo' 'Xinwei Guo' 'Xinwei Guo'<br>'Xi...
# https://openalex.org/W4394402060  ['Xinwei Guo' 'Xinwei Guo' 'Xinwei Guo'<br>'Zu...
# https://openalex.org/W4394415133  ['Xinwei Guo' 'Xinwei Guo' 'Xinwei Guo'<br>'Zu...
# https://openalex.org/W4394419950  ['Xinwei Guo' 'Xinwei Guo' 'Xinwei Guo'<br>'Xi...
# https://openalex.org/W4394503207  ['Xinwei Guo' 'Xinwei Guo' 'Xinwei Guo'<br>'Zu...
#
#                                                                    wrapped_keywords  \
# paper_id
# https://openalex.org/W4393413673  ['evolutionarily conserved', 'estimated<br>pos...
# https://openalex.org/W4393529795  ['evolutionarily conserved', 'estimated<br>pos...
# https://openalex.org/W4393593906  ['Class Integrative Estimation',<br>'Annotatio...
# https://openalex.org/W4393617317  ['Class Integrative Estimation',<br>'Annotatio...
# https://openalex.org/W4393641940  ['Class Integrative Estimation',<br>'Annotatio...
# https://openalex.org/W4393736355  ['Class Integrative Estimation',<br>'Annotatio...
# https://openalex.org/W4393742852  ['Class Integrative Estimation',<br>'Annotatio...
# https://openalex.org/W4393819632  ['Class Integrative Estimation',<br>'Annotatio...
# https://openalex.org/W4394071783  ['continuous inflorescence removal',<br>'inflo...
# https://openalex.org/W4394150963  ['continuous inflorescence removal',<br>'inflo...
# https://openalex.org/W4394155442  ['continuous inflorescence removal',<br>'inflo...
# https://openalex.org/W4394363642  ['Additional file', 'Fagopyrum<br>dibotrys', '...
# https://openalex.org/W4394402060  ['continuous inflorescence removal',<br>'inflo...
# https://openalex.org/W4394415133  ['Fagopyrum dibotrys', 'Additional<br>file', '...
# https://openalex.org/W4394419950  ['continuous inflorescence removal',<br>'inflo...
# https://openalex.org/W4394503207  ['continuous inflorescence removal',<br>'inflo...
#
#                                                                              source  \
# paper_id
# https://openalex.org/W4393413673  Zenodo (CERN European Organization for Nuclear...
# https://openalex.org/W4393529795  Zenodo (CERN European Organization for Nuclear...
# https://openalex.org/W4393593906  Zenodo (CERN European Organization for Nuclear...
# https://openalex.org/W4393617317  Zenodo (CERN European Organization for Nuclear...
# https://openalex.org/W4393641940  Zenodo (CERN European Organization for Nuclear...
# https://openalex.org/W4393736355  Zenodo (CERN European Organization for Nuclear...
# https://openalex.org/W4393742852  Zenodo (CERN European Organization for Nuclear...
# https://openalex.org/W4393819632  Zenodo (CERN European Organization for Nuclear...
# https://openalex.org/W4394071783                                           Figshare
# https://openalex.org/W4394150963                                           Figshare
# https://openalex.org/W4394155442                                           Figshare
# https://openalex.org/W4394363642                                           Figshare
# https://openalex.org/W4394402060                                           Figshare
# https://openalex.org/W4394415133                                           Figshare
# https://openalex.org/W4394419950                                           Figshare
# https://openalex.org/W4394503207                                           Figshare
#
#                                  source_type country_count  collab_countries
# paper_id
# https://openalex.org/W4393413673  repository             3      [US, CH, CN]
# https://openalex.org/W4393529795  repository             3      [US, CH, CN]
# https://openalex.org/W4393593906  repository             3      [US, CH, CN]
# https://openalex.org/W4393617317  repository             3      [US, CH, CN]
# https://openalex.org/W4393641940  repository             3      [US, CH, CN]
# https://openalex.org/W4393736355  repository             3      [US, CH, CN]
# https://openalex.org/W4393742852  repository             3      [US, CH, CN]
# https://openalex.org/W4393819632  repository             3      [US, CH, CN]
# https://openalex.org/W4394071783  repository             3      [US, CN, GB]
# https://openalex.org/W4394150963  repository             3      [US, CN, GB]
# https://openalex.org/W4394155442  repository             3      [US, CN, GB]
# https://openalex.org/W4394363642  repository             3      [US, CN, GB]
# https://openalex.org/W4394402060  repository             3      [US, CN, GB]
# https://openalex.org/W4394415133  repository             3      [US, CN, GB]
# https://openalex.org/W4394419950  repository             3      [US, CN, GB]
# https://openalex.org/W4394503207  repository             3      [US, CN, GB]
#
# [16 rows x 21 columns]

# %%
import networkx as nx
from pyvis.network import Network
import igraph as ig # for g

# %%
dfinfo["funder_list"] = dfinfo["grants"].apply(get_funder_names)
dfinfo["wrapped_funder_list"] = dfinfo["funder_list"].apply(str).apply(wrap_it)

# %%
dfinfo.to_pickle('updatejammingdfinfo2d.pkl')

# %%
dfinfo[['id','keywords','wrapped_keywords','wrapped_funder_list']].head()
# Out:
#                                                                 id  \
# id
# https://openalex.org/W3041133507  https://openalex.org/W3041133507
# https://openalex.org/W4225854071  https://openalex.org/W4225854071
# https://openalex.org/W4283271244  https://openalex.org/W4283271244
# https://openalex.org/W3171517418  https://openalex.org/W3171517418
# https://openalex.org/W4220999759  https://openalex.org/W4220999759
#
#                                                                            keywords  \
# id
# https://openalex.org/W3041133507  [Transfer Learning, Learning, Transfer, transf...
# https://openalex.org/W4225854071  [Immune Humoral Response, Waning Immune Humora...
# https://openalex.org/W4283271244  [World Health Organization, Health Organizatio...
# https://openalex.org/W3171517418  [chemotherapy versus chemotherapy, chemotherap...
# https://openalex.org/W4220999759  [human reference genome, human genome, genome,...
#
#                                                                    wrapped_keywords  \
# id
# https://openalex.org/W3041133507  ['Transfer Learning', 'Learning',<br>'Transfer...
# https://openalex.org/W4225854071  ['Immune Humoral Response', 'Waning<br>Immune ...
# https://openalex.org/W4283271244  ['World Health Organization', 'Health<br>Organ...
# https://openalex.org/W3171517418  ['chemotherapy versus chemotherapy',<br>'chemo...
# https://openalex.org/W4220999759  ['human reference genome', 'human<br>genome', ...
#
#                                                                 wrapped_funder_list
# id
# https://openalex.org/W3041133507  ['National Natural Science Foundation of<br>Ch...
# https://openalex.org/W4225854071                                                 []
# https://openalex.org/W4283271244                                                 []
# https://openalex.org/W3171517418  ['Bristol-Myers Squibb', 'Ono<br>Pharmaceutical']
# https://openalex.org/W4220999759                                                 []

# %%
kw_dict = dfinfo['keywords'].to_dict()

# %%
dc = dftriple[dftriple['paper_cluster'] == 10].copy()
dc.shape
# Out:
# (4730, 27)

# %%
[x for row in dc['funder_list'].tolist() for x in row][:10]
# Out:
# ['Istituto Nazionale di Astrofisica',
#  'Istituto Nazionale di Astrofisica',
#  'Istituto Nazionale di Astrofisica',
#  'Istituto Nazionale di Astrofisica',
#  'Istituto Nazionale di Astrofisica',
#  'Istituto Nazionale di Astrofisica',
#  'Istituto Nazionale di Astrofisica',
#  'Istituto Nazionale di Astrofisica',
#  'Istituto Nazionale di Astrofisica',
#  'Istituto Nazionale di Astrofisica']

# %%
kw_dict = dfinfo['keywords'].to_dict()

# add in the affiliations as nodes as well; that row, author, paper, affil. all three get links. ok.
def create_nx_graph(df: pd.DataFrame, cl:int) -> nx.Graph:
    """
    takes the dataframe df, and creates the undirected graph
    from the source and target columns for each row.
    """
    g = nx.Graph() # dc['paper_cluster'] == cl
    dc = df[df['paper_cluster'] == cl]
    author_counts = dc['paper_author_id'].tolist()
    author_counts_dict = {c:author_counts.count(c) for c in author_counts}
    affiliation_counts = dc['id'].tolist()
    affiliation_counts_dict = {c:affiliation_counts.count(c) for c in affiliation_counts}
    source_counts = dc['source'].tolist()
    source_counts_dict = {c:source_counts.count(c) for c in source_counts}
    funder_counts = [x for row in dc['funder_list'].tolist() for x in row]
    funder_counts_dict = {c:funder_counts.count(c) for c in funder_counts}
    for index, row in df[df['paper_cluster'] == cl].iterrows():
        g.add_node(row['paper_id'], group='work', title=row['paper_title'])
        g.add_node(row['paper_author_id'], title=row['paper_author_display_name'],
                   group='author',value = author_counts_dict[row['paper_author_id']])
        g.add_node(row['id'], group='affiliation',
                   title=row['display_name'] + '\n' + row['country_code'],
                  value = affiliation_counts_dict[row['id']])
        if row['source']:
            g.add_node(row['source'], group=row['source_type'],
                      title=row['source'] + ' :\n ' + row['source_type'],
                      value=source_counts_dict[row['source']])
            g.add_edge(
                row['paper_id'],
                row['source'],
                title=row['paper_title'] + ' :\n ' + str(row['paper_publication_date']) +  \
                ' :\n' + row['source'] + ' :\n ' + \
                row['source_type'],
              #  weight = df[(df['paper_id'] == row['paper_id']) & \
              #              (df['source'] == row['source'])]['paper_cluster_score'].sum()
               # weight = row['paper_cluster_score']
            )
            g.add_edge(
                row['paper_author_id'],
                row['source'],
                title=row['paper_author_display_name'] + ':\n' + row['source'],
             #   weight = df[(df['paper_author_id'] == row['paper_author_id']) & \
              #              (df['source'] == row['source'])]['paper_cluster_score'].sum()
               # weight = row['paper_cluster_score']
            )
        if len(row['funder_list']) > 0:
            for f in row['funder_list']:
                g.add_node(f, group='funder',
                          title=str(f),
                          value = founder_counts_dict[f]),
                g.add_edge(
                       row['paper_id'],
                       f,
                       title=row['paper_title'] + ':\n ' +  str(row['paper_publication_date']) + \
                       ' :\n' + str(f),
                  #  weight = row['paper_cluster_score']
                   )
                g.add_edge(
                       f,
                       row['paper_author_id'],
                       title=row['paper_author_display_name'] + ' :\n ' + \
                       str(f),
                  #  weight = row['paper_cluster_score']
                       
                   )
                g.add_edge(
                       f,
                       row['id'],
                       title=row['display_name'] + '\n' + row['country_code'] + ' :\n ' + \
                       str(f)  ,
                  #  weight = row['paper_cluster_score']
                   )  
                if row["source"]:
                    g.add_edge(
                        f,
                        row["source"],
                        title=row["source"] + ' :\n' + str(f),
                     #   weight = row['paper_cluster_score']
                    )
        g.nodes[row['paper_id']]['title'] = (
            row['paper_title'] + ' :\n ' + str(row['paper_publication_date'] + ':\n' + 
            '\n'.join(kw_dict[row['paper_id']]))
        )
        g.nodes[row['paper_author_id']]['title'] = (
            row['paper_author_display_name']
        )
        g.add_edge(
            row['paper_id'],
            row['paper_author_id'],
        title=row['paper_title'] + ' :\n ' + row['paper_author_display_name'] + ' :\n ' + \
            row['paper_raw_affiliation_string'],
         #   weight = row['paper_cluster_score']
        )
        g.add_edge(
            row['paper_author_id'],
            row['id'],
            title=row['paper_author_display_name'] + ' :\n ' + \
            row['display_name'] + ' :\n ' + row['country_code'],
          #  weight = row['paper_cluster_score']
        )
        g.add_edge(
            row['paper_id'],
            row['id'],
            title=row['paper_title'] + ' :\n ' + str(row['paper_publication_date']) + ':\n' + 
            row['display_name'] + ' :\n ' + row['country_code'],
         #   weight = row['paper_cluster_score']
        )
        
    g_ig = ig.Graph.from_networkx(g) # assign 'x', and 'y' to g before returning
    #layout = g_ig.layout_auto()
    #layout = g_ig.layout_davidson_harel()
    layout = g_ig.layout_umap(min_dist = 2, epochs = 500)
    # https://igraph.org/python/tutorial/0.9.6/visualisation.html
    coords = layout.coords
    allnodes = list(g.nodes())
    coords_dict = {allnodes[i]:(coords[i][0], coords[i][1]) for i in range(len(allnodes))}
    for i in g.nodes():
        g.nodes[i]['x'] = 250 * coords_dict[i][0] # the scale factor needed 
        g.nodes[i]['y'] = 250 * coords_dict[i][1]
    return g

# %%
def create_pyvis_html(cl: int, filename: str = "pyvis_coauthorships_graph.html"):
    """
    wrapper function that calls create_nx_graph to finally 
    produce an interactive pyvis standalone html file
    """
    g_nx = create_nx_graph(dftriple, cl);
    h = Network(height="1000px",
          #  heading="Mitigations and Techniques Relationships",
                width="100%",
                cdn_resources="remote", # can grab the visjs library to make this local if needed
            # probably should
                bgcolor="#222222",
            neighborhood_highlight=True,
              # default_node_size=1,
                font_color="white",
                directed=False,
               # select_menu=True,
                filter_menu=True,
                notebook=False,
               )
    #h.repulsion()
    h.from_nx(g_nx, show_edge_weights=False)
    #h.barnes_hut()
    #h.repulsion(node_distance=40,
    #            central_gravity=-0.2, spring_length=5, spring_strength=0.005, damping=0.09)
    neighbor_map = h.get_adj_list()
   # for node in h.nodes:
   #     if node['group'] == 'author':
   #         a = list(neighbor_map[node["id"]]) # want to insert a "\n" into every third element of a
   #     if node['group'] == 'work':
   #         a = list(neighbor_map[node["id"]])
   #     i = 3
   #     while i < len(a):
   #         a.insert(i, "\n")
   #         i += 4
   #     node["title"] += "\n Neighbors: \n" + " | ".join(a)
   #     node["value"] = len(neighbor_map[node["id"]]) 
# "physics": {
#    "enabled": false
#  },
    h.set_options(
    """
const options = {
  "interaction": {
    "navigationButtons": false
  },
 "physics": {
     "enabled": false
 },
  "edges": {
    "color": {
        "inherit": true
    },
    "setReferenceSize": null,
    "setReference": {
        "angle": 0.7853981633974483
    },
    "smooth": {
        "forceDirection": "none"
    }
  }
  }
    """
    )
    #h.show_buttons(filter_=['physics'])
  #  h.barnes_hut()
    #h.repulsion()
    try:
        path = './tmp'
        h.save_graph(f"{path}/{filename}")
        HtmlFile = open(f"{path}/{filename}","r",
                        encoding='utf-8')
    except:
        h.save_graph(f"{filename}")
        HtmlFile = open(f"{filename}", "r",
                        encoding="utf-8")
    return h

# %%
dfinfo.shape
# Out:
# (31109, 21)

# %%
dftime = dfinfo[['cluster','probability','publication_date']].copy()

# %%
dftime['publication_datetime'] = pd.to_datetime(dftime['publication_date'])

# %%
def get_time_series(dg, cl:int):
    """
    takes dg and the cluster number cl
    and returns a time series chart
    by month, y-axis is the article count
    """
    dftime = dg[dg.cluster == cl][['cluster','probability','publication_date']].copy()
    dftime['date'] = pd.to_datetime(dftime['publication_date'])
    dftime.sort_values('date', inplace=True)
    #by_month = pd.to_datetime(dftime['date']).dt.to_period('M').value_counts().sort_index()
    #by_month.index = pd.PeriodIndex(by_month.index)
    #df_month = by_month.rename_axis('month').reset_index(name='counts')
    return dftime

# %%
import altair as alt
#alt.data_transformers.enable("data_server")

# %%
sources_list = dftriple['source'].unique().tolist()
type(sources_list), len(sources_list)
# Out:
# (list, 5247)

# %%
def get_source_json(s:str):
    """
    s is an openalex Sources display_name
    return that Sources object
    """
    source_json = Sources().search_filter(display_name = s).get()
    a = source_json[0]['type']
    if "homepage_url" in source_json[0] and source_json[0]['homepage_url']:
       # print(f"{s} has homepage_url and type {source_json[0]['type']}")
        return source_json[0]["homepage_url"]
    else:
        return None

# %%
sources_list[5]
# Out:
# 'Nature'

# %%
sj0 = get_source_json(sources_list[5])
sj0
# Out:
# 'https://www.nature.com/nature/'

# %%
def get_display_page_dict(sl:list):
    """
    sl is a list of Sources display_name values
    returns the dictionary mapping
    display_names with homepage_url values."""
    mapping_dict = dict()
    for s in tqdm(sl):
        try:
            mapping_dict[s] = get_source_json(s)
        except:
            pass
    return mapping_dict

# %%
source_page_dict = get_display_page_dict(sources_list)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████| 5247/5247 [51:00<00:00,  1.71it/s]

# %%
len(source_page_dict)
# Out:
# 4667

# %%
import pickle

with open("updatesource_page_dict.pkl", "wb") as f:
    pickle.dump(source_page_dict, f)

# %%
with open("updatesource_page_dict.pkl", "rb") as f:
    source_dict = pickle.load(f)

# %%
dftriple.columns
# Out:
# Index(['id', 'display_name', 'ror', 'country_code', 'type', 'lineage',
#        'paper_id', 'paper_raw_affiliation_strings', 'paper_author_position',
#        'paper_doi', 'paper_title', 'paper_abstract', 'paper_publication_date',
#        'paper_publication_year', 'paper_grants', 'paper_locations',
#        'paper_is_corrresponding', 'paper_x', 'paper_y', 'paper_cluster',
#        'paper_cluster_score', 'paper_author_id', 'paper_author_display_name',
#        'paper_author_orcid', 'source', 'source_type', 'funder_list'],
#       dtype='object')

# %%
dftriple[['source','source_type','paper_cluster']].head()
# Out:
#                     source source_type paper_cluster
# 0  Proceedings of the IEEE     journal           183
# 1  Proceedings of the IEEE     journal           183
# 2  Proceedings of the IEEE     journal           183
# 3  Proceedings of the IEEE     journal           183
# 4  Proceedings of the IEEE     journal           183

# %%
#source_dict

# %%
def get_journals_cluster_sort(dc:pd.DataFrame, cl:int):
    """
    restricts the dataframe dc to cluster value cl
    and returns the results grouped by source (where
    source_type == 'journal') sorted
    by the some of probablity descending
    """
    dg = dc[dc['paper_cluster'] == cl].copy()
    print(cl)
    dv = dg[dg['source_type'] == 'journal'].groupby(['source'])['paper_cluster_score'].sum().to_frame()
    dv.sort_values('paper_cluster_score', ascending=False, inplace=True)
    dv['journal'] = dv.index
    dv['hompage_url'] = dv['journal'].map(source_dict)
    kw = centroids[centroids.cluster == cl]['keywords'].iloc[0]
    return dv, kw

# %%
dv, kw = get_journals_cluster_sort(dftriple, 183)
dv.head()
# Out:
# 183
#                                                    paper_cluster_score  \
# source
# IEEE transactions on pattern analysis and machi...          470.547493
# IEEE transactions on circuits and systems for v...               239.0
# IEEE transactions on image processing                       230.987161
# IEEE transactions on multimedia                             188.651563
# IEEE transactions on neural networks and learni...            147.9426
#
#                                                                                               journal  \
# source
# IEEE transactions on pattern analysis and machi...  IEEE transactions on pattern analysis and mach...
# IEEE transactions on circuits and systems for v...  IEEE transactions on circuits and systems for ...
# IEEE transactions on image processing                           IEEE transactions on image processing
# IEEE transactions on multimedia                                       IEEE transactions on multimedia
# IEEE transactions on neural networks and learni...  IEEE transactions on neural networks and learn...
#
#                                                                                           hompage_url
# source
# IEEE transactions on pattern analysis and machi...           http://www.computer.org/portal/web/tpami
# IEEE transactions on circuits and systems for v...  http://ieeexplore.ieee.org/servlet/opac?punumb...
# IEEE transactions on image processing               http://ieeexplore.ieee.org/servlet/opac?punumb...
# IEEE transactions on multimedia                     http://ieeexplore.ieee.org/servlet/opac?punumb...
# IEEE transactions on neural networks and learni...  http://cis.ieee.org/ieee-transactions-on-neura...

# %%
def get_conferences_cluster_sort(dc:pd.DataFrame, cl:int):
    """
    restricts the dataframe dc to cluster value cl
    and returns the results grouped by source (where
    source_type == 'journal') sorted
    by the some of probablity descending
    """
    dg = dc[dc['paper_cluster'] == cl].copy()
    print(cl)
    dv = dg[dg['source_type'] == 'conference'].groupby(['source'])['paper_cluster_score'].sum().to_frame()
    dv.sort_values('paper_cluster_score', ascending=False, inplace=True)
    dv['conference'] = dv.index
    dv['homepage_url'] = dv['conference'].map(source_dict)
    kw = centroids[centroids.cluster == cl]['keywords'].iloc[0]
    return dv, kw

# %%
affils_list = dftriple['display_name'].unique().tolist()
type(affils_list), len(affils_list)
# Out:
# (list, 21126)

# %%
affil_json = Institutions().search_filter(display_name = affils_list[0]).get()

# %%
affils_list = dftriple['display_name'].unique().tolist()
type(affils_list), len(affils_list)

affil_json = Institutions().search_filter(display_name = affils_list[1]).get()

def get_affil_json(s:str):
    """
    s is an openalex Sources display_name
    return that Sources object
    """
    affil_json = Institutions().search_filter(display_name = s).get()
    #a = source_json[0]['type']
    if "geo" in affil_json[0]:
       # print(f"{s} has homepage_url and type {source_json[0]['type']}")
        return affil_json[0]["geo"]["latitude"], affil_json[0]["geo"]["longitude"]
    else:
        return None, None
    
def get_display_geo_dict(sl:list):
    """
    sl is a list of Institution display_name values
    returns the dictionary mapping
    display_names with (latitude, longitude) values."""
    mapping_dict = dict()
    for s in tqdm(sl):
        try:
            mapping_dict[s] = get_affil_json(s)
        except:
            pass
    return mapping_dict

affil_geo_dict = get_display_geo_dict(affils_list)


import pickle

with open("updateaffil_geo_dict.pkl", "wb") as f:
    pickle.dump(affil_geo_dict, f)
# Out:
# 100%|█████████████████████████████████████████████████████████████████| 21126/21126 [3:02:08<00:00,  1.93it/s]

# %%
dfinfo['abstract'] = dfinfo['title'].map(dftriple.set_index('paper_title')['paper_abstract'].to_dict())
dfinfo.to_pickle('updatejammingdfinfo2d.pkl')
